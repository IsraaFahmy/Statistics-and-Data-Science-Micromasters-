# %% [markdown]
# <a href="https://colab.research.google.com/github/IsraaFahmy/Statistics-and-Data-Science-Micromasters-/blob/main/MITx%2018.6501x%20/Notebooks/stats_w4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Data Exploration Review
#
# Motivation: https://www.kaggle.com/datasets/ranitsarkar01/yulu-bike-sharing-data
# #DATASETS:
# https://drive.google.com/drive/folders/19tlww2iAAE3_9jXk0ebgDkp168YphNsd

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
bikes <- read_csv('yulu_bike.csv')
head(bikes)
# Out:
# Rows: 10886 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (11): season, holiday, workingday, weather, temp, atemp, humidity, wind...
# dttm  (1): datetime
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   datetime            season holiday workingday weather temp atemp  humidity
# 1 2011-01-01 00:00:00 1      0       0          1       9.84 14.395 81
# 2 2011-01-01 01:00:00 1      0       0          1       9.02 13.635 80
# 3 2011-01-01 02:00:00 1      0       0          1       9.02 13.635 80
# 4 2011-01-01 03:00:00 1      0       0          1       9.84 14.395 75
# 5 2011-01-01 04:00:00 1      0       0          1       9.84 14.395 75
# 6 2011-01-01 05:00:00 1      0       0          2       9.84 12.880 75
#   windspeed casual registered count
# 1 0.0000    3      13         16
# ...

# %%
ggplot(bikes,aes(x=workingday,y=count))+
  geom_col()+
  theme_bw()+
  labs(x='workingday',y='Count')
# Out:
# plot without title

# %%
ggplot(bikes,aes(x=season,y=count))+
  geom_col()+
  theme_bw()+
  labs(x='Season',y='Count')
# Out:
# plot without title

# %%
bikes %>%
  group_by(season) %>%
  summarise(mean(count))
# Out:
#   season mean(count)
# 1 1      116.3433
# 2 2      215.2514
# 3 3      234.4171
# 4 4      198.9883

# %%
bikes %>%
  group_by(weather) %>%
  summarise(mean(count))
# Out:
#   weather mean(count)
# 1 1       205.2368
# 2 2       178.9555
# 3 3       118.8463
# 4 4       164.0000

# %%
bikes %>%
  group_by(weather) %>%
  count()
# Out:
#   weather n
# 1 1       7192
# 2 2       2834
# 3 3        859
# 4 4          1

# %%
ggplot(bikes, aes(x = temp, y = count)) +
  geom_point() +
  geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# #### Confidence intervals

# %% [markdown]
# Sample of 1000 students -- average score was 82%.  Is that the population average?
#
# Go test another 1000 students -- average an 82%?
#
# Normal distribution captured 66 - 95 -- 99 % of the data within 1, 2, and 3 standard deviations.
#
# - Distribution of scores is normal
# - Standard Deviation is 10.
#
# **EX**: Sample of students on SAT math.
#
# Sample Size = 500
#
# Standard Deviation of Scores is 100.
#
# The scores will be distributed according to a Normal Distribution with mean = sample mean and standard deviation;
#
# $$\sigma/\sqrt{n}$$
# $\mu = 480$?

# %%
#upper conf interval
mu <- 480
se <- 100/sqrt(500)
upper <- mu + 2*se
upper
# Out:
# [1] 488.9443

# %%
#lower conf interval
lower<- mu - 2*se
lower
# Out:
# [1] 471.0557

# %%
print(lower)
print(upper)
# Out:
# [1] 471.0557
# [1] 488.9443

# %% [markdown]
# EX1: SAT Writing.  Sample is 1000, s.d. of population is 80.  Mean of sample is 432;
# - build a 99% confidence interval.
# mean = 432

# %%
upper <- 432 + 3*(80/sqrt(1000))
lower <- 432 - 3*(80/sqrt(1000))
print(upper)
print(lower)
# Out:
# [1] 439.5895
# [1] 424.4105

# %% [markdown]
# $$z \times \frac{\sigma}{\sqrt{n}}$$

# %% [markdown]
# 1. The National Association of Colleges and Employers Salary Survey shows that the current class of college graduates received an initial salary offer of 48,127.  A School conducted a Simple Random Sample of 300 students and obtained a 95% confidence interval of (46,143, 47,987).  What can you conclude about the difference between the average starting salary of recent graduate at given school and the overall NACE average.  Use complete sentences to write a short summary.
#
# 2. To increase business, the owner of a restaurant is running a promotion in which a customer’s bill can be
# randomly selected to receive a discount. When a customer’s bill is printed, a program in the cash register
# randomly determines whether the customer will receive a discount on the bill. The program was written to
# generate a discount with a probability of 0.2, that is, giving 20 percent of the bills a discount in the long run.
# However, the owner is concerned that the program has a mistake that results in the program not generating the
# intended long-run proportion of 0.2.
# The owner selected a random sample of bills and found that only 15 percent of them received discounts. A
# confidence interval for p, the proportion of bills that will receive a discount in the long run, is $0.15 \pm 0.06$.
#
#
#   - Consider the confidence interval $0.15 \pm 0.06$.
#
#    - Does the confidence interval provide convincing statistical evidence that the program is not working as
# intended? Justify your answer.
#    - Does the confidence interval provide convincing statistical evidence that the program generates the
# discount with a probability of 0.2 ? Justify your answer.
#
# - A second random sample of bills was taken that was four times the size of the original sample. In the second
# sample 15 percent of the bills received the discount.
#
#     - Determine the value of the margin of error based on the second sample of bills that would be used to
# compute an interval for p with the same confidence level as that of the original interval.
#
#  - Based on the margin of error that was obtained from the second sample, what do you conclude
# about whether the program is working as intended? Justify your answer.

# %% [markdown]
# 3. In a survey of small businesses, a survey was conducted to gauge views on social media.  There were 3240 businesses examined, and a random sample of 250 were selected and asked whether or not they use social media as an advertising tool for their business.  142 businesses claimed social media was an integral part of their business, the remainder did not use social media. Construct a 95% confidence interval for this example.

# %%
250*(142/250)*(108/250)
# Out:
# [1] 61.344

# %%
142/250 + 2*sqrt(61.34)/sqrt(250)
# Out:
# [1] 1.558677

# %%
250*142/250 - 2*61.34/sqrt(250)
# Out:
# [1] 134.241

# %%
250*142/250 + 2*61.34/sqrt(250)
# Out:
# [1] 149.759

# %% [markdown]
# #### Hypothesis Tests
#
# *P-Values*
#
# The probability assuming our null hypothesis $H_0$ is true that the test statistic would take a value as extreme or more extreme than that actually observed.
#
# -----
#
# Back to our example from college tuition borrowing. (A difference in tuition of 425, standard deviation of 353.)
#
# - Formulate our null hypothesis
# $$H_0 = \text{There is no difference in average scholarships between groups}$$
# $$H_a = \text{There is a difference in average scholarships between groups}$$
#
# - Determine the $z$-score for found difference
# - Look up probability using $z$-scores

# %%
#zscore
(425 - 0)/353
# Out:
# [1] 1.203966

# %%
#random 1000 normal values
x <- rnorm(1000)

# %%
#make it a dataframe
df <- data.frame(x = c(x))

# %%
#plot it
ggplot(df, aes(x = x)) +
  geom_histogram() +
  geom_vline(xintercept = 1.2)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
#hypthesis of one variable -- aka is the mean some value
mileage <- read_csv('mileage.csv')
head(mileage)
# Out:
# Rows: 16 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): Car, Mileage
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Car Mileage
# 1 1   28.0
# 2 2   25.7
# 3 3   25.8
# 4 4   28.0
# 5 5   28.5
# 6 6   29.8

# %%
# Out:
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# [1] NA

# %%
x <- mileage['Mileage']
t.test(x, mu = 30)
# Out:
# 	One Sample t-test
#
# data:  x
# t = -4.9693, df = 15, p-value = 0.0001681
# alternative hypothesis: true mean is not equal to 30
# 95 percent confidence interval:
#  27.36542 28.94708
# sample estimates:
# mean of x
#  28.15625

# %%
#test for two groups means
g1 <- rnorm(1000, mean = 100, sd = 3)
g2 <- rnorm(1000, mean = 100.1, sd = 3)
t.test(g1, g2)
# Out:
# 	Welch Two Sample t-test
#
# data:  g1 and g2
# t = -0.31767, df = 1995.3, p-value = 0.7508
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.2978741  0.2148263
# sample estimates:
# mean of x mean of y
#  100.0854  100.1269

# %%
t.test(count ~ holiday, data = bikes)
# Out:
# 	Welch Two Sample t-test
#
# data:  count by holiday
# t = 0.60419, df = 331.56, p-value = 0.5461
# alternative hypothesis: true difference in means between group 0 and group 1 is not equal to 0
# 95 percent confidence interval:
#  -13.22790  24.95558
# sample estimates:
# mean in group 0 mean in group 1
#        191.7417        185.8778

# %% [markdown]
# #### Problems
#
# 1. Given the `mileage` dataset, test the claim on the cars sticker that the average mpg for city driving is 30 mpg.
# (Here we are testing difference from average of 30 so we use `t.test(x, mu = 30)`)
#
# 2. If we increase our food intake, we generally gain weight.  In one study, researchers fed 16 non-obese adults, age 25-36 1000 excess calories a day.  According to theory, 3500 extra calories will translate into a weight gain of 1 point, therefore we expect each of the subjects to gain 16 pounds.  the `wtgain` dataset contains the before and after eight week period gains.
#
#  a. Create a new column to represent the weight change of each subject.
#
#  b. Find the mean and standard deviation for the change.
#
#  c. Determine the 95% confidence interval for weight change and interpret in complete sentences.
#
#  d. Test the null hypothesis that the mean weight gain is 16 lbs.  What do you conclude?
#
# 3. Insurance adjusters are concerned about the high estimates they are receiving from Jocko's Garage.  To see if the estimates are unreasonably high, each of 10 damaged cars was take to Jocko's and to another garage and the estimates were recorded in the `jocko.csv` file.
#
#  a. Create a new column that represents the difference in prices from the two garages. Find the mean and standard deviation of the difference.
#
#  b. Test the null hypothesis that there is no difference between the estimates at the 0.05 significance level.
#
#  c. What do you conclude?

# %% [markdown]
# #### Question on cycles
#
# - Working Day has effect on number of electric cycles rented
#
# - No. of cycles rented similar or different in different seasons
#
# - No. of cycles rented similar or different in different weather
